# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import random
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
import gc
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.trainers.data_adapters.py_dataset_adapter')

# %%
# Bloco 1: Preparação dos dados
B_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/division_imgs/carcinoma_basocelular/train/"
M_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/division_imgs/melanoma/train/"
D_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/dataset_input/"

def visualize_samples(image_dir, title, sample_size=6):
    image_files = os.listdir(image_dir)
    samples = random.sample(image_files, sample_size)
    f, ax = plt.subplots(2, 3, figsize=(15, 9))
    for i in range(sample_size):
        im = cv2.imread(os.path.join(image_dir, samples[i]))
        ax[i // 3, i % 3].imshow(im)
        ax[i // 3, i % 3].axis('off')
    f.suptitle(title, fontsize=20)
    plt.show()

def load_images_from_directory(directory, label, image_size=(224, 224)):
    data = []
    labels = []
    image_files = os.listdir(directory)
    for image_file in image_files:
        image_path = os.path.join(directory, image_file)
        image = cv2.imread(image_path)
        if image is not None:
            image_from_array = Image.fromarray(image, 'RGB')
            resized_image = image_from_array.resize(image_size)
            data.append(np.array(resized_image))
            labels.append(label)
    return data, labels

visualize_samples(B_DIR, 'Carcinoma Basocelular')
visualize_samples(M_DIR, 'Melanoma')
visualize_samples(D_DIR, 'Desconhecido')

# Carrega e prepara dados
basal_data, basal_labels = load_images_from_directory(B_DIR, 0)
melanoma_data, melanoma_labels = load_images_from_directory(M_DIR, 1)

# Balanceamento das classes
min_class_size = min(len(basal_data), len(melanoma_data))
basal_data = basal_data[:min_class_size]
basal_labels = basal_labels[:min_class_size]
melanoma_data = melanoma_data[:min_class_size]
melanoma_labels = melanoma_labels[:min_class_size]

# Combina e embaralha os dados
data = np.array(basal_data + melanoma_data)
labels = np.array(basal_labels + melanoma_labels)
shuffled_indices = np.arange(len(data))
np.random.shuffle(shuffled_indices)
data = data[shuffled_indices]
labels = labels[shuffled_indices]

# Salva arrays
np.save("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/feats_train_30", data)
np.save("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/labels_train_30", labels)

# %%
# Bloco 2: treinamento e avaliação com o KFold

data = np.load("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/feats_train_30.npy")
labels = np.load("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/labels_train_30.npy")

# Divide dados em trainamento e teste (80% para o KFold, 20% para teste nos 5 modelos)
split_index = int(0.8 * len(data))
x_train, x_test = data[:split_index], data[split_index:]
y_train, y_test = labels[:split_index], labels[split_index:]

# Normaliza os dados
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
num_classes = len(np.unique(labels))
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

trainAug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)

# Criação do modelo
def create_model():
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet', 
        include_top=False, 
        input_shape=(224, 224, 3)
    )
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Configuração callbacks para salvar o melhor modelo em cada fold
def create_callbacks():
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=1, mode='min', min_delta=1e-10)
    checkpoint = ModelCheckpoint("best_model_fold.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    return [reduce_lr, checkpoint]

# Plotagem da matriz de confusão
def plot_confusion_matrix(cm, classes, fold=''):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.ylabel('Rótulo verdadeiro')
    plt.xlabel('Rótulo previsto')
    plt.title(f'Matriz de Confusão {fold}')
    plt.show()

# Cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_val_accuracies = []
best_f1_scores = []
best_model_paths = []

for fold, (train_index, val_index) in enumerate(kf.split(x_train)):
    print(f"Treinando o fold {fold + 1}/{kf.n_splits}...")
    x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    model = create_model()
    
    # Treina o modelo
    model.fit(
        trainAug.flow(x_train_fold, y_train_fold, batch_size=16),
        validation_data=(x_val_fold, y_val_fold),
        epochs=30,
        callbacks=create_callbacks()
    )

    # Avalia o modelo
    val_loss, val_accuracy = model.evaluate(x_val_fold, y_val_fold, verbose=0)
    print(f'Fold {fold + 1} - Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')

    # Plota matriz de confusão para o fold atual
    y_val_pred = model.predict(x_val_fold, batch_size=16)
    y_val_pred_classes = np.argmax(y_val_pred, axis=1)
    y_val_true = np.argmax(y_val_fold, axis=1)
    confusion_mtx = confusion_matrix(y_val_true, y_val_pred_classes)
    plot_confusion_matrix(confusion_mtx, classes=range(num_classes), fold=f'Fold {fold + 1}')

    # Calcula o F1-score para o fold atual
    report = classification_report(y_val_true, y_val_pred_classes, output_dict=True, target_names=['BCC', 'Melanoma'])
    f1_score = (report['BCC']['f1-score'] + report['Melanoma']['f1-score']) / 2

    best_val_accuracies.append(val_accuracy)
    best_f1_scores.append(f1_score)
    
    # Salva o melhor modelo
    best_model_path = f'/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/skin_model_keras/epoch_30/best_model_fold_{fold + 1}.keras'
    model.save(best_model_path)
    best_model_paths.append(best_model_path)

    # Limpa memória
    del x_train_fold, x_val_fold, y_train_fold, y_val_fold, model
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# Treinando o fold 1/5...
# Epoch 1/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.7834 - loss: 0.5585
# Epoch 1: val_loss improved from inf to 0.49237, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 252s 900ms/step - accuracy: 0.7836 - loss: 0.5580 - val_accuracy: 0.8286 - val_loss: 0.4924 - learning_rate: 0.0010
# Epoch 2/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.8693 - loss: 0.3350
# Epoch 2: val_loss did not improve from 0.49237
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 239s 905ms/step - accuracy: 0.8693 - loss: 0.3350 - val_accuracy: 0.4943 - val_loss: 7.2942 - learning_rate: 0.0010
# Epoch 3/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.8671 - loss: 0.3469
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 3: val_loss did not improve from 0.49237
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 239s 904ms/step - accuracy: 0.8671 - loss: 0.3469 - val_accuracy: 0.5133 - val_loss: 7.9352 - learning_rate: 0.0010
# Epoch 4/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.9087 - loss: 0.2282
# Epoch 4: val_loss did not improve from 0.49237
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 239s 903ms/step - accuracy: 0.9087 - loss: 0.2281 - val_accuracy: 0.7434 - val_loss: 2.4988 - learning_rate: 3.0000e-04
# Epoch 5/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.9338 - loss: 0.1836
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 5: val_loss did not improve from 0.49237
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 239s 904ms/step - accuracy: 0.9338 - loss: 0.1836 - val_accuracy: 0.8390 - val_loss: 0.7781 - learning_rate: 3.0000e-04
# Epoch 6/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9577 - loss: 0.1178
# Epoch 6: val_loss improved from 0.49237 to 0.41059, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9577 - loss: 0.1179 - val_accuracy: 0.8778 - val_loss: 0.4106 - learning_rate: 9.0000e-05
# Epoch 7/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9582 - loss: 0.1164
# Epoch 7: val_loss improved from 0.41059 to 0.30590, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9582 - loss: 0.1164 - val_accuracy: 0.9062 - val_loss: 0.3059 - learning_rate: 9.0000e-05
# Epoch 8/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9653 - loss: 0.0978
# Epoch 8: val_loss did not improve from 0.30590
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9653 - loss: 0.0978 - val_accuracy: 0.8797 - val_loss: 0.3343 - learning_rate: 9.0000e-05
# Epoch 9/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.9737 - loss: 0.0666
# Epoch 9: val_loss improved from 0.30590 to 0.25167, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 905ms/step - accuracy: 0.9737 - loss: 0.0667 - val_accuracy: 0.9091 - val_loss: 0.2517 - learning_rate: 9.0000e-05
# Epoch 10/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9739 - loss: 0.0669
# Epoch 10: val_loss improved from 0.25167 to 0.22446, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.9739 - loss: 0.0669 - val_accuracy: 0.9223 - val_loss: 0.2245 - learning_rate: 9.0000e-05
# Epoch 11/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9747 - loss: 0.0680
# Epoch 11: val_loss improved from 0.22446 to 0.18035, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.9747 - loss: 0.0680 - val_accuracy: 0.9403 - val_loss: 0.1803 - learning_rate: 9.0000e-05
# Epoch 12/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9794 - loss: 0.0531
# Epoch 12: val_loss did not improve from 0.18035
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 239s 905ms/step - accuracy: 0.9793 - loss: 0.0531 - val_accuracy: 0.9261 - val_loss: 0.2169 - learning_rate: 9.0000e-05
# Epoch 13/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9875 - loss: 0.0420
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 13: val_loss did not improve from 0.18035
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 905ms/step - accuracy: 0.9875 - loss: 0.0420 - val_accuracy: 0.9328 - val_loss: 0.2036 - learning_rate: 9.0000e-05
# Epoch 14/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9877 - loss: 0.0332
# Epoch 14: val_loss improved from 0.18035 to 0.17620, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9877 - loss: 0.0332 - val_accuracy: 0.9328 - val_loss: 0.1762 - learning_rate: 2.7000e-05
# Epoch 15/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9949 - loss: 0.0194
# Epoch 15: val_loss improved from 0.17620 to 0.16772, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9949 - loss: 0.0194 - val_accuracy: 0.9451 - val_loss: 0.1677 - learning_rate: 2.7000e-05
# Epoch 16/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9921 - loss: 0.0267
# Epoch 16: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 905ms/step - accuracy: 0.9921 - loss: 0.0267 - val_accuracy: 0.9432 - val_loss: 0.1953 - learning_rate: 2.7000e-05
# Epoch 17/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9917 - loss: 0.0224
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 17: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9917 - loss: 0.0224 - val_accuracy: 0.9441 - val_loss: 0.1809 - learning_rate: 2.7000e-05
# Epoch 18/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9972 - loss: 0.0106
# Epoch 18: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9972 - loss: 0.0107 - val_accuracy: 0.9413 - val_loss: 0.1905 - learning_rate: 8.1000e-06
# Epoch 19/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9957 - loss: 0.0127
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 19: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9956 - loss: 0.0127 - val_accuracy: 0.9413 - val_loss: 0.1985 - learning_rate: 8.1000e-06
# Epoch 20/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9964 - loss: 0.0157
# Epoch 20: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9964 - loss: 0.0157 - val_accuracy: 0.9422 - val_loss: 0.2041 - learning_rate: 2.4300e-06
# Epoch 21/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9949 - loss: 0.0145
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 21: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9949 - loss: 0.0145 - val_accuracy: 0.9413 - val_loss: 0.2053 - learning_rate: 2.4300e-06
# Epoch 22/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9939 - loss: 0.0183
# Epoch 22: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.9939 - loss: 0.0183 - val_accuracy: 0.9403 - val_loss: 0.2087 - learning_rate: 7.2900e-07
# Epoch 23/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9952 - loss: 0.0148
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 23: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9952 - loss: 0.0148 - val_accuracy: 0.9403 - val_loss: 0.2112 - learning_rate: 7.2900e-07
# Epoch 24/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9966 - loss: 0.0112
# Epoch 24: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9966 - loss: 0.0113 - val_accuracy: 0.9394 - val_loss: 0.2134 - learning_rate: 2.1870e-07
# Epoch 25/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9954 - loss: 0.0115
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
#
# Epoch 25: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 906ms/step - accuracy: 0.9954 - loss: 0.0115 - val_accuracy: 0.9394 - val_loss: 0.2148 - learning_rate: 2.1870e-07
# Epoch 26/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9958 - loss: 0.0102
# Epoch 26: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9958 - loss: 0.0102 - val_accuracy: 0.9394 - val_loss: 0.2164 - learning_rate: 6.5610e-08
# Epoch 27/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9953 - loss: 0.0128
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
#
# Epoch 27: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9953 - loss: 0.0128 - val_accuracy: 0.9394 - val_loss: 0.2175 - learning_rate: 6.5610e-08
# Epoch 28/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9956 - loss: 0.0136
# Epoch 28: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9956 - loss: 0.0136 - val_accuracy: 0.9375 - val_loss: 0.2183 - learning_rate: 1.9683e-08
# Epoch 29/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9932 - loss: 0.0137
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
#
# Epoch 29: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9932 - loss: 0.0137 - val_accuracy: 0.9375 - val_loss: 0.2189 - learning_rate: 1.9683e-08
# Epoch 30/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9949 - loss: 0.0129
# Epoch 30: val_loss did not improve from 0.16772
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9949 - loss: 0.0129 - val_accuracy: 0.9375 - val_loss: 0.2196 - learning_rate: 5.9049e-09
# Fold 1 - Val Loss: 0.2196, Val Accuracy: 0.9375
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step
# Treinando o fold 2/5...
# Epoch 1/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.7853 - loss: 0.5084
# Epoch 1: val_loss improved from inf to 7.60267, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 255s 913ms/step - accuracy: 0.7854 - loss: 0.5080 - val_accuracy: 0.5047 - val_loss: 7.6027 - learning_rate: 0.0010
# Epoch 2/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.8754 - loss: 0.3162
# Epoch 2: val_loss did not improve from 7.60267
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.8754 - loss: 0.3162 - val_accuracy: 0.5047 - val_loss: 8.8006 - learning_rate: 0.0010
# Epoch 3/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.8918 - loss: 0.2727
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 3: val_loss did not improve from 7.60267
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.8918 - loss: 0.2728 - val_accuracy: 0.5047 - val_loss: 7.6219 - learning_rate: 0.0010
# Epoch 4/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9113 - loss: 0.2316
# Epoch 4: val_loss did not improve from 7.60267
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9113 - loss: 0.2316 - val_accuracy: 0.5066 - val_loss: 8.5964 - learning_rate: 3.0000e-04
# Epoch 5/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9449 - loss: 0.1504
# Epoch 5: val_loss improved from 7.60267 to 6.84741, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9449 - loss: 0.1505 - val_accuracy: 0.5303 - val_loss: 6.8474 - learning_rate: 3.0000e-04
# Epoch 6/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9474 - loss: 0.1431
# Epoch 6: val_loss improved from 6.84741 to 2.60429, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 909ms/step - accuracy: 0.9474 - loss: 0.1431 - val_accuracy: 0.6742 - val_loss: 2.6043 - learning_rate: 3.0000e-04
# Epoch 7/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9579 - loss: 0.1268
# Epoch 7: val_loss did not improve from 2.60429
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9579 - loss: 0.1268 - val_accuracy: 0.6562 - val_loss: 2.6123 - learning_rate: 3.0000e-04
# Epoch 8/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9643 - loss: 0.1041
# Epoch 8: val_loss improved from 2.60429 to 0.96638, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9643 - loss: 0.1041 - val_accuracy: 0.7955 - val_loss: 0.9664 - learning_rate: 3.0000e-04
# Epoch 9/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9734 - loss: 0.0814
# Epoch 9: val_loss improved from 0.96638 to 0.50403, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9734 - loss: 0.0814 - val_accuracy: 0.8722 - val_loss: 0.5040 - learning_rate: 3.0000e-04
# Epoch 10/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9707 - loss: 0.0774
# Epoch 10: val_loss did not improve from 0.50403
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9707 - loss: 0.0774 - val_accuracy: 0.7945 - val_loss: 1.6088 - learning_rate: 3.0000e-04
# Epoch 11/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9733 - loss: 0.0724
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 11: val_loss did not improve from 0.50403
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9732 - loss: 0.0724 - val_accuracy: 0.8191 - val_loss: 1.0316 - learning_rate: 3.0000e-04
# Epoch 12/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9839 - loss: 0.0609
# Epoch 12: val_loss did not improve from 0.50403
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9839 - loss: 0.0609 - val_accuracy: 0.8191 - val_loss: 0.9844 - learning_rate: 9.0000e-05
# Epoch 13/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9912 - loss: 0.0293
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 13: val_loss did not improve from 0.50403
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9912 - loss: 0.0293 - val_accuracy: 0.8580 - val_loss: 0.6985 - learning_rate: 9.0000e-05
# Epoch 14/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9952 - loss: 0.0188
# Epoch 14: val_loss improved from 0.50403 to 0.42194, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9952 - loss: 0.0188 - val_accuracy: 0.9053 - val_loss: 0.4219 - learning_rate: 2.7000e-05
# Epoch 15/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9936 - loss: 0.0191
# Epoch 15: val_loss improved from 0.42194 to 0.40259, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9936 - loss: 0.0191 - val_accuracy: 0.9091 - val_loss: 0.4026 - learning_rate: 2.7000e-05
# Epoch 16/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9951 - loss: 0.0152
# Epoch 16: val_loss improved from 0.40259 to 0.32088, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9951 - loss: 0.0152 - val_accuracy: 0.9223 - val_loss: 0.3209 - learning_rate: 2.7000e-05
# Epoch 17/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9961 - loss: 0.0126
# Epoch 17: val_loss improved from 0.32088 to 0.30038, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9961 - loss: 0.0126 - val_accuracy: 0.9233 - val_loss: 0.3004 - learning_rate: 2.7000e-05
# Epoch 18/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9988 - loss: 0.0075
# Epoch 18: val_loss improved from 0.30038 to 0.29991, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9988 - loss: 0.0075 - val_accuracy: 0.9242 - val_loss: 0.2999 - learning_rate: 2.7000e-05
# Epoch 19/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9953 - loss: 0.0102
# Epoch 19: val_loss improved from 0.29991 to 0.27522, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9953 - loss: 0.0102 - val_accuracy: 0.9337 - val_loss: 0.2752 - learning_rate: 2.7000e-05
# Epoch 20/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9987 - loss: 0.0083
# Epoch 20: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9987 - loss: 0.0083 - val_accuracy: 0.9299 - val_loss: 0.2992 - learning_rate: 2.7000e-05
# Epoch 21/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9967 - loss: 0.0063
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 21: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9968 - loss: 0.0063 - val_accuracy: 0.9309 - val_loss: 0.3043 - learning_rate: 2.7000e-05
# Epoch 22/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9967 - loss: 0.0079
# Epoch 22: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9967 - loss: 0.0079 - val_accuracy: 0.9337 - val_loss: 0.2908 - learning_rate: 8.1000e-06
# Epoch 23/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9969 - loss: 0.0111
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 23: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9969 - loss: 0.0111 - val_accuracy: 0.9309 - val_loss: 0.2932 - learning_rate: 8.1000e-06
# Epoch 24/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9982 - loss: 0.0047
# Epoch 24: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 912ms/step - accuracy: 0.9982 - loss: 0.0047 - val_accuracy: 0.9347 - val_loss: 0.2870 - learning_rate: 2.4300e-06
# Epoch 25/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9986 - loss: 0.0042
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 25: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9347 - val_loss: 0.2877 - learning_rate: 2.4300e-06
# Epoch 26/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9982 - loss: 0.0047
# Epoch 26: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9982 - loss: 0.0047 - val_accuracy: 0.9347 - val_loss: 0.2889 - learning_rate: 7.2900e-07
# Epoch 27/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9990 - loss: 0.0043
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 27: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 0.9356 - val_loss: 0.2886 - learning_rate: 7.2900e-07
# Epoch 28/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9958 - loss: 0.0121
# Epoch 28: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9958 - loss: 0.0121 - val_accuracy: 0.9356 - val_loss: 0.2896 - learning_rate: 2.1870e-07
# Epoch 29/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9996 - loss: 0.0034
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
#
# Epoch 29: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9996 - loss: 0.0034 - val_accuracy: 0.9356 - val_loss: 0.2905 - learning_rate: 2.1870e-07
# Epoch 30/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9995 - loss: 0.0029
# Epoch 30: val_loss did not improve from 0.27522
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9356 - val_loss: 0.2912 - learning_rate: 6.5610e-08
# Fold 2 - Val Loss: 0.2912, Val Accuracy: 0.9356
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step
# Treinando o fold 3/5...
# Epoch 1/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.7992 - loss: 0.5138
# Epoch 1: val_loss improved from inf to 3.32320, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 256s 918ms/step - accuracy: 0.7993 - loss: 0.5135 - val_accuracy: 0.4905 - val_loss: 3.3232 - learning_rate: 0.0010
# Epoch 2/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.8699 - loss: 0.3404
# Epoch 2: val_loss did not improve from 3.32320
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.8699 - loss: 0.3403 - val_accuracy: 0.4896 - val_loss: 6.1882 - learning_rate: 0.0010
# Epoch 3/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.8916 - loss: 0.2826
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 3: val_loss did not improve from 3.32320
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.8915 - loss: 0.2826 - val_accuracy: 0.4896 - val_loss: 5.4245 - learning_rate: 0.0010
# Epoch 4/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9104 - loss: 0.2268
# Epoch 4: val_loss did not improve from 3.32320
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9104 - loss: 0.2267 - val_accuracy: 0.4962 - val_loss: 6.6209 - learning_rate: 3.0000e-04
# Epoch 5/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9335 - loss: 0.1672
# Epoch 5: val_loss improved from 3.32320 to 0.84870, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9335 - loss: 0.1671 - val_accuracy: 0.7292 - val_loss: 0.8487 - learning_rate: 3.0000e-04
# Epoch 6/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9521 - loss: 0.1238
# Epoch 6: val_loss did not improve from 0.84870
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 907ms/step - accuracy: 0.9521 - loss: 0.1238 - val_accuracy: 0.8134 - val_loss: 0.8669 - learning_rate: 3.0000e-04
# Epoch 7/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9565 - loss: 0.1316
# Epoch 7: val_loss improved from 0.84870 to 0.47703, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9565 - loss: 0.1316 - val_accuracy: 0.8655 - val_loss: 0.4770 - learning_rate: 3.0000e-04
# Epoch 8/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.9547 - loss: 0.1137
# Epoch 8: val_loss improved from 0.47703 to 0.34838, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9547 - loss: 0.1137 - val_accuracy: 0.9138 - val_loss: 0.3484 - learning_rate: 3.0000e-04
# Epoch 9/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.9711 - loss: 0.0835
# Epoch 9: val_loss did not improve from 0.34838
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 240s 908ms/step - accuracy: 0.9711 - loss: 0.0835 - val_accuracy: 0.8504 - val_loss: 0.6170 - learning_rate: 3.0000e-04
# Epoch 10/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9751 - loss: 0.0712
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 10: val_loss did not improve from 0.34838
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9751 - loss: 0.0713 - val_accuracy: 0.9252 - val_loss: 0.3790 - learning_rate: 3.0000e-04
# Epoch 11/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9825 - loss: 0.0499
# Epoch 11: val_loss did not improve from 0.34838
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 909ms/step - accuracy: 0.9825 - loss: 0.0499 - val_accuracy: 0.9186 - val_loss: 0.3789 - learning_rate: 9.0000e-05
# Epoch 12/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9914 - loss: 0.0328
# Epoch 12: val_loss improved from 0.34838 to 0.25972, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9914 - loss: 0.0328 - val_accuracy: 0.9337 - val_loss: 0.2597 - learning_rate: 9.0000e-05
# Epoch 13/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9914 - loss: 0.0222
# Epoch 13: val_loss did not improve from 0.25972
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9914 - loss: 0.0222 - val_accuracy: 0.9261 - val_loss: 0.2797 - learning_rate: 9.0000e-05
# Epoch 14/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9955 - loss: 0.0196
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 14: val_loss did not improve from 0.25972
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9955 - loss: 0.0196 - val_accuracy: 0.9309 - val_loss: 0.2917 - learning_rate: 9.0000e-05
# Epoch 15/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9908 - loss: 0.0210
# Epoch 15: val_loss did not improve from 0.25972
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9908 - loss: 0.0210 - val_accuracy: 0.9356 - val_loss: 0.2635 - learning_rate: 2.7000e-05
# Epoch 16/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9981 - loss: 0.0080
# Epoch 16: val_loss improved from 0.25972 to 0.25238, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9981 - loss: 0.0080 - val_accuracy: 0.9451 - val_loss: 0.2524 - learning_rate: 2.7000e-05
# Epoch 17/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9976 - loss: 0.0067
# Epoch 17: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9422 - val_loss: 0.2673 - learning_rate: 2.7000e-05
# Epoch 18/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9979 - loss: 0.0071
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 18: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9979 - loss: 0.0071 - val_accuracy: 0.9422 - val_loss: 0.2894 - learning_rate: 2.7000e-05
# Epoch 19/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9986 - loss: 0.0045
# Epoch 19: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9441 - val_loss: 0.2786 - learning_rate: 8.1000e-06
# Epoch 20/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9987 - loss: 0.0082
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 20: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9987 - loss: 0.0082 - val_accuracy: 0.9460 - val_loss: 0.2720 - learning_rate: 8.1000e-06
# Epoch 21/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9987 - loss: 0.0096
# Epoch 21: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9987 - loss: 0.0096 - val_accuracy: 0.9479 - val_loss: 0.2697 - learning_rate: 2.4300e-06
# Epoch 22/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9984 - loss: 0.0049
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 22: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9984 - loss: 0.0049 - val_accuracy: 0.9479 - val_loss: 0.2706 - learning_rate: 2.4300e-06
# Epoch 23/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9984 - loss: 0.0059
# Epoch 23: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9984 - loss: 0.0059 - val_accuracy: 0.9508 - val_loss: 0.2719 - learning_rate: 7.2900e-07
# Epoch 24/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9970 - loss: 0.0065
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 24: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9970 - loss: 0.0065 - val_accuracy: 0.9489 - val_loss: 0.2739 - learning_rate: 7.2900e-07
# Epoch 25/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9983 - loss: 0.0045
# Epoch 25: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9983 - loss: 0.0045 - val_accuracy: 0.9489 - val_loss: 0.2750 - learning_rate: 2.1870e-07
# Epoch 26/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9981 - loss: 0.0046
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
#
# Epoch 26: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9489 - val_loss: 0.2760 - learning_rate: 2.1870e-07
# Epoch 27/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9999 - loss: 0.0025
# Epoch 27: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9479 - val_loss: 0.2767 - learning_rate: 6.5610e-08
# Epoch 28/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9973 - loss: 0.0074
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
#
# Epoch 28: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9973 - loss: 0.0074 - val_accuracy: 0.9479 - val_loss: 0.2778 - learning_rate: 6.5610e-08
# Epoch 29/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9980 - loss: 0.0057
# Epoch 29: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9479 - val_loss: 0.2782 - learning_rate: 1.9683e-08
# Epoch 30/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9993 - loss: 0.0033
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
#
# Epoch 30: val_loss did not improve from 0.25238
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.9479 - val_loss: 0.2788 - learning_rate: 1.9683e-08
# Fold 3 - Val Loss: 0.2788, Val Accuracy: 0.9479
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step
# Treinando o fold 4/5...
# Epoch 1/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.7900 - loss: 0.5251
# Epoch 1: val_loss improved from inf to 4.45752, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 259s 919ms/step - accuracy: 0.7901 - loss: 0.5247 - val_accuracy: 0.5189 - val_loss: 4.4575 - learning_rate: 0.0010
# Epoch 2/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.8750 - loss: 0.3322
# Epoch 2: val_loss did not improve from 4.45752
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.8750 - loss: 0.3322 - val_accuracy: 0.5189 - val_loss: 10.3583 - learning_rate: 0.0010
# Epoch 3/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9011 - loss: 0.2608
# Epoch 3: val_loss improved from 4.45752 to 0.81757, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9011 - loss: 0.2608 - val_accuracy: 0.7320 - val_loss: 0.8176 - learning_rate: 0.0010
# Epoch 4/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9091 - loss: 0.2404
# Epoch 4: val_loss did not improve from 0.81757
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9091 - loss: 0.2404 - val_accuracy: 0.5189 - val_loss: 3.2198 - learning_rate: 0.0010
# Epoch 5/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9116 - loss: 0.2283
# Epoch 5: val_loss improved from 0.81757 to 0.55272, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 912ms/step - accuracy: 0.9116 - loss: 0.2283 - val_accuracy: 0.8201 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 6/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.9070 - loss: 0.2530
# Epoch 6: val_loss did not improve from 0.55272
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 910ms/step - accuracy: 0.9069 - loss: 0.2530 - val_accuracy: 0.5189 - val_loss: 15.3878 - learning_rate: 0.0010
# Epoch 7/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.9176 - loss: 0.2141
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 7: val_loss did not improve from 0.55272
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9176 - loss: 0.2140 - val_accuracy: 0.5180 - val_loss: 16.9312 - learning_rate: 0.0010
# Epoch 8/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9486 - loss: 0.1512
# Epoch 8: val_loss did not improve from 0.55272
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 912ms/step - accuracy: 0.9486 - loss: 0.1512 - val_accuracy: 0.7083 - val_loss: 3.5902 - learning_rate: 3.0000e-04
# Epoch 9/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9510 - loss: 0.1207
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 9: val_loss did not improve from 0.55272
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 911ms/step - accuracy: 0.9510 - loss: 0.1207 - val_accuracy: 0.8523 - val_loss: 0.8298 - learning_rate: 3.0000e-04
# Epoch 10/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9731 - loss: 0.0761
# Epoch 10: val_loss improved from 0.55272 to 0.36812, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9731 - loss: 0.0761 - val_accuracy: 0.9006 - val_loss: 0.3681 - learning_rate: 9.0000e-05
# Epoch 11/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9802 - loss: 0.0616
# Epoch 11: val_loss improved from 0.36812 to 0.26904, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9802 - loss: 0.0617 - val_accuracy: 0.9195 - val_loss: 0.2690 - learning_rate: 9.0000e-05
# Epoch 12/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9819 - loss: 0.0552
# Epoch 12: val_loss improved from 0.26904 to 0.26636, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9818 - loss: 0.0552 - val_accuracy: 0.9214 - val_loss: 0.2664 - learning_rate: 9.0000e-05
# Epoch 13/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9866 - loss: 0.0416
# Epoch 13: val_loss improved from 0.26636 to 0.25233, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9866 - loss: 0.0416 - val_accuracy: 0.9318 - val_loss: 0.2523 - learning_rate: 9.0000e-05
# Epoch 14/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9841 - loss: 0.0442
# Epoch 14: val_loss improved from 0.25233 to 0.23301, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 912ms/step - accuracy: 0.9841 - loss: 0.0442 - val_accuracy: 0.9299 - val_loss: 0.2330 - learning_rate: 9.0000e-05
# Epoch 15/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9905 - loss: 0.0281
# Epoch 15: val_loss did not improve from 0.23301
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9905 - loss: 0.0281 - val_accuracy: 0.9309 - val_loss: 0.2374 - learning_rate: 9.0000e-05
# Epoch 16/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9858 - loss: 0.0395
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 16: val_loss did not improve from 0.23301
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9858 - loss: 0.0395 - val_accuracy: 0.9347 - val_loss: 0.2452 - learning_rate: 9.0000e-05
# Epoch 17/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9947 - loss: 0.0156
# Epoch 17: val_loss improved from 0.23301 to 0.22521, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9947 - loss: 0.0156 - val_accuracy: 0.9337 - val_loss: 0.2252 - learning_rate: 2.7000e-05
# Epoch 18/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9942 - loss: 0.0185
# Epoch 18: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9942 - loss: 0.0185 - val_accuracy: 0.9337 - val_loss: 0.2341 - learning_rate: 2.7000e-05
# Epoch 19/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9941 - loss: 0.0144
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 19: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9941 - loss: 0.0144 - val_accuracy: 0.9299 - val_loss: 0.2338 - learning_rate: 2.7000e-05
# Epoch 20/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9945 - loss: 0.0164
# Epoch 20: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9945 - loss: 0.0164 - val_accuracy: 0.9290 - val_loss: 0.2410 - learning_rate: 8.1000e-06
# Epoch 21/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9973 - loss: 0.0099
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 21: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9973 - loss: 0.0099 - val_accuracy: 0.9290 - val_loss: 0.2568 - learning_rate: 8.1000e-06
# Epoch 22/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9952 - loss: 0.0143
# Epoch 22: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 241s 912ms/step - accuracy: 0.9952 - loss: 0.0143 - val_accuracy: 0.9280 - val_loss: 0.2620 - learning_rate: 2.4300e-06
# Epoch 23/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9943 - loss: 0.0157
# Epoch 23: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 23: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9943 - loss: 0.0157 - val_accuracy: 0.9271 - val_loss: 0.2624 - learning_rate: 2.4300e-06
# Epoch 24/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9979 - loss: 0.0093
# Epoch 24: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9979 - loss: 0.0093 - val_accuracy: 0.9242 - val_loss: 0.2668 - learning_rate: 7.2900e-07
# Epoch 25/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9958 - loss: 0.0147
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 25: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9958 - loss: 0.0147 - val_accuracy: 0.9242 - val_loss: 0.2695 - learning_rate: 7.2900e-07
# Epoch 26/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9957 - loss: 0.0094
# Epoch 26: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9957 - loss: 0.0094 - val_accuracy: 0.9233 - val_loss: 0.2718 - learning_rate: 2.1870e-07
# Epoch 27/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9972 - loss: 0.0097
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
#
# Epoch 27: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9972 - loss: 0.0097 - val_accuracy: 0.9233 - val_loss: 0.2739 - learning_rate: 2.1870e-07
# Epoch 28/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9958 - loss: 0.0156
# Epoch 28: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9958 - loss: 0.0156 - val_accuracy: 0.9233 - val_loss: 0.2760 - learning_rate: 6.5610e-08
# Epoch 29/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9967 - loss: 0.0111
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
#
# Epoch 29: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 913ms/step - accuracy: 0.9967 - loss: 0.0111 - val_accuracy: 0.9242 - val_loss: 0.2769 - learning_rate: 6.5610e-08
# Epoch 30/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9933 - loss: 0.0186
# Epoch 30: val_loss did not improve from 0.22521
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9933 - loss: 0.0186 - val_accuracy: 0.9242 - val_loss: 0.2781 - learning_rate: 1.9683e-08
# Fold 4 - Val Loss: 0.2781, Val Accuracy: 0.9242
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 163ms/step
# Treinando o fold 5/5...
# Epoch 1/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.7891 - loss: 0.5083
# Epoch 1: val_loss improved from inf to 2.86516, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 258s 924ms/step - accuracy: 0.7893 - loss: 0.5080 - val_accuracy: 0.5616 - val_loss: 2.8652 - learning_rate: 0.0010
# Epoch 2/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.8862 - loss: 0.3012
# Epoch 2: val_loss improved from 2.86516 to 1.51104, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.8862 - loss: 0.3013 - val_accuracy: 0.5123 - val_loss: 1.5110 - learning_rate: 0.0010
# Epoch 3/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.8955 - loss: 0.2816
# Epoch 3: val_loss improved from 1.51104 to 1.15996, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.8955 - loss: 0.2816 - val_accuracy: 0.7936 - val_loss: 1.1600 - learning_rate: 0.0010
# Epoch 4/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.8952 - loss: 0.2879
# Epoch 4: val_loss did not improve from 1.15996
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.8952 - loss: 0.2879 - val_accuracy: 0.6903 - val_loss: 1.7552 - learning_rate: 0.0010
# Epoch 5/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9128 - loss: 0.2324
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 5: val_loss did not improve from 1.15996
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 914ms/step - accuracy: 0.9128 - loss: 0.2324 - val_accuracy: 0.7907 - val_loss: 1.3251 - learning_rate: 0.0010
# Epoch 6/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9448 - loss: 0.1501
# Epoch 6: val_loss improved from 1.15996 to 1.10126, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9448 - loss: 0.1501 - val_accuracy: 0.8002 - val_loss: 1.1013 - learning_rate: 3.0000e-04
# Epoch 7/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9605 - loss: 0.1067
# Epoch 7: val_loss did not improve from 1.10126
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9605 - loss: 0.1067 - val_accuracy: 0.7424 - val_loss: 1.1705 - learning_rate: 3.0000e-04
# Epoch 8/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9657 - loss: 0.1095
# Epoch 8: val_loss improved from 1.10126 to 0.46500, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 916ms/step - accuracy: 0.9658 - loss: 0.1095 - val_accuracy: 0.8864 - val_loss: 0.4650 - learning_rate: 3.0000e-04
# Epoch 9/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9696 - loss: 0.0790
# Epoch 9: val_loss improved from 0.46500 to 0.45820, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9696 - loss: 0.0791 - val_accuracy: 0.8627 - val_loss: 0.4582 - learning_rate: 3.0000e-04
# Epoch 10/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9728 - loss: 0.0780
# Epoch 10: val_loss improved from 0.45820 to 0.26757, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 916ms/step - accuracy: 0.9728 - loss: 0.0780 - val_accuracy: 0.9223 - val_loss: 0.2676 - learning_rate: 3.0000e-04
# Epoch 11/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9764 - loss: 0.0706
# Epoch 11: val_loss did not improve from 0.26757
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9763 - loss: 0.0706 - val_accuracy: 0.8902 - val_loss: 0.5609 - learning_rate: 3.0000e-04
# Epoch 12/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9683 - loss: 0.0897
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 12: val_loss did not improve from 0.26757
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9683 - loss: 0.0897 - val_accuracy: 0.9242 - val_loss: 0.2952 - learning_rate: 3.0000e-04
# Epoch 13/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9799 - loss: 0.0590
# Epoch 13: val_loss did not improve from 0.26757
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9799 - loss: 0.0589 - val_accuracy: 0.9309 - val_loss: 0.2983 - learning_rate: 9.0000e-05
# Epoch 14/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9929 - loss: 0.0222
# Epoch 14: val_loss improved from 0.26757 to 0.24791, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9929 - loss: 0.0222 - val_accuracy: 0.9451 - val_loss: 0.2479 - learning_rate: 9.0000e-05
# Epoch 15/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9916 - loss: 0.0236
# Epoch 15: val_loss did not improve from 0.24791
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9916 - loss: 0.0236 - val_accuracy: 0.9413 - val_loss: 0.2524 - learning_rate: 9.0000e-05
# Epoch 16/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9943 - loss: 0.0172
# Epoch 16: val_loss improved from 0.24791 to 0.22727, saving model to best_model_fold.keras
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9943 - loss: 0.0172 - val_accuracy: 0.9422 - val_loss: 0.2273 - learning_rate: 9.0000e-05
# Epoch 17/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9934 - loss: 0.0220
# Epoch 17: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9934 - loss: 0.0220 - val_accuracy: 0.9470 - val_loss: 0.2350 - learning_rate: 9.0000e-05
# Epoch 18/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.9944 - loss: 0.0171
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 18: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 244s 921ms/step - accuracy: 0.9944 - loss: 0.0172 - val_accuracy: 0.9441 - val_loss: 0.2282 - learning_rate: 9.0000e-05
# Epoch 19/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 876ms/step - accuracy: 0.9980 - loss: 0.0083
# Epoch 19: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 918ms/step - accuracy: 0.9980 - loss: 0.0083 - val_accuracy: 0.9441 - val_loss: 0.2414 - learning_rate: 2.7000e-05
# Epoch 20/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9977 - loss: 0.0109
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 20: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9977 - loss: 0.0109 - val_accuracy: 0.9451 - val_loss: 0.2584 - learning_rate: 2.7000e-05
# Epoch 21/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9963 - loss: 0.0075
# Epoch 21: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9963 - loss: 0.0075 - val_accuracy: 0.9517 - val_loss: 0.2586 - learning_rate: 8.1000e-06
# Epoch 22/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9987 - loss: 0.0042
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 22: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9517 - val_loss: 0.2591 - learning_rate: 8.1000e-06
# Epoch 23/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9991 - loss: 0.0043
# Epoch 23: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 916ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9498 - val_loss: 0.2668 - learning_rate: 2.4300e-06
# Epoch 24/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9986 - loss: 0.0058
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 24: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 917ms/step - accuracy: 0.9986 - loss: 0.0058 - val_accuracy: 0.9479 - val_loss: 0.2691 - learning_rate: 2.4300e-06
# Epoch 25/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9980 - loss: 0.0086
# Epoch 25: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 917ms/step - accuracy: 0.9980 - loss: 0.0086 - val_accuracy: 0.9479 - val_loss: 0.2725 - learning_rate: 7.2900e-07
# Epoch 26/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9962 - loss: 0.0100
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 26: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9962 - loss: 0.0100 - val_accuracy: 0.9489 - val_loss: 0.2760 - learning_rate: 7.2900e-07
# Epoch 27/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9982 - loss: 0.0051
# Epoch 27: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9489 - val_loss: 0.2781 - learning_rate: 2.1870e-07
# Epoch 28/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9983 - loss: 0.0048
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
#
# Epoch 28: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 242s 915ms/step - accuracy: 0.9983 - loss: 0.0048 - val_accuracy: 0.9460 - val_loss: 0.2802 - learning_rate: 2.1870e-07
# Epoch 29/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9991 - loss: 0.0038
# Epoch 29: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 917ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9470 - val_loss: 0.2815 - learning_rate: 6.5610e-08
# Epoch 30/30
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.9992 - loss: 0.0031
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
#
# Epoch 30: val_loss did not improve from 0.22727
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 243s 916ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9470 - val_loss: 0.2828 - learning_rate: 6.5610e-08
# Fold 5 - Val Loss: 0.2828, Val Accuracy: 0.9470
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 12s 166ms/step

# %%
# Bloco 3: Avaliação dos Modelos com Dados de Teste

all_test_accuracies = []
all_test_f1_scores = []

for idx, model_path in enumerate(best_model_paths):
    print(f"Carregando e avaliando o modelo do Fold {idx + 1}...")
    model = load_model(model_path)
    
    # Avalia o modelo no conjunto de teste
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    y_test_pred = model.predict(x_test, batch_size=16)
    y_test_pred_classes = np.argmax(y_test_pred, axis=1)
    y_test_true = np.argmax(y_test, axis=1)
    
    # Relatório de classificação para o conjunto de teste
    report = classification_report(y_test_true, y_test_pred_classes, target_names=['BCC', 'Melanoma'])
    print(f"Modelo do Fold {idx + 1} - Relatório de Classificação no teste:\n{report}")
    
    # Calcula a média das métricas
    accuracy = test_accuracy
    f1_scores = classification_report(y_test_true, y_test_pred_classes, output_dict=True, target_names=['BCC', 'Melanoma'])
    f1_score = (f1_scores['BCC']['f1-score'] + f1_scores['Melanoma']['f1-score']) / 2

    all_test_accuracies.append(accuracy)
    all_test_f1_scores.append(f1_score)

    # Limpa memória
    del model
    gc.collect()
    tf.keras.backend.clear_session()

# Médias dos Resultados dos Modelos
mean_test_accuracy = np.mean(all_test_accuracies)
mean_test_f1_score = np.mean(all_test_f1_scores)

print(f"Média da Acurácia no Conjunto de Teste: {mean_test_accuracy:.4f}")
print(f"Média do F1-Score no Conjunto de Teste: {mean_test_f1_score:.4f}")

# Determina o melhor modelo baseado na acurácia
best_fold = np.argmax(all_test_accuracies) + 1
print(f"O melhor modelo é o do Fold {best_fold} com acurácia de {all_test_accuracies[best_fold-1]:.4f}.")
# Out:
# Carregando e avaliando o modelo do Fold 1...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step
# Modelo do Fold 1 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.95      0.92      0.94       662
#     Melanoma       0.92      0.95      0.94       658
#
#     accuracy                           0.94      1320
#    macro avg       0.94      0.94      0.94      1320
# weighted avg       0.94      0.94      0.94      1320
#
# Carregando e avaliando o modelo do Fold 2...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step
# Modelo do Fold 2 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.94      0.92      0.93       662
#     Melanoma       0.92      0.94      0.93       658
#
#     accuracy                           0.93      1320
#    macro avg       0.93      0.93      0.93      1320
# weighted avg       0.93      0.93      0.93      1320
#
# Carregando e avaliando o modelo do Fold 3...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step
# Modelo do Fold 3 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.96      0.93      0.94       662
#     Melanoma       0.93      0.96      0.94       658
#
#     accuracy                           0.94      1320
#    macro avg       0.94      0.94      0.94      1320
# weighted avg       0.94      0.94      0.94      1320
#
# Carregando e avaliando o modelo do Fold 4...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step
# Modelo do Fold 4 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.96      0.91      0.93       662
#     Melanoma       0.91      0.96      0.94       658
#
#     accuracy                           0.93      1320
#    macro avg       0.94      0.93      0.93      1320
# weighted avg       0.94      0.93      0.93      1320
#
# Carregando e avaliando o modelo do Fold 5...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step
# Modelo do Fold 5 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.97      0.91      0.94       662
#     Melanoma       0.92      0.97      0.94       658
#
#     accuracy                           0.94      1320
#    macro avg       0.94      0.94      0.94      1320
# weighted avg       0.94      0.94      0.94      1320
#
# Média da Acurácia no Conjunto de Teste: 0.9367
# Média do F1-Score no Conjunto de Teste: 0.9366
# O melhor modelo é o do Fold 3 com acurácia de 0.9424.
