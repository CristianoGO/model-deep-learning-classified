# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import random
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
import gc
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.trainers.data_adapters.py_dataset_adapter')
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='PIL.Image')

# Diretórios de imagens
B_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/division_imgs/carcinoma_basocelular/train/"
M_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/division_imgs/melanoma/train/"
R_DIR = "/home/cristiano/www/skin_cancer_prediction/ISIC_2020/dataset_input/"

# %%
# Função para visualizar amostras
def visualize_samples(image_dir, title, sample_size=6):
    image_files = os.listdir(image_dir)
    samples = random.sample(image_files, sample_size)
    f, ax = plt.subplots(2, 3, figsize=(15, 9))
    for i in range(sample_size):
        im = cv2.imread(os.path.join(image_dir, samples[i]))
        ax[i // 3, i % 3].imshow(im)
        ax[i // 3, i % 3].axis('off')
    f.suptitle(title, fontsize=20)
    plt.show()

# Função para carregar imagens de diretório
def load_images_from_directory(directory, label, image_size=(224, 224)):
    data = []
    labels = []
    image_files = os.listdir(directory)
    for image_file in image_files:
        image_path = os.path.join(directory, image_file)
        image = cv2.imread(image_path)
        if image is not None:
            image_from_array = Image.fromarray(image, 'RGB')
            resized_image = image_from_array.resize(image_size)
            data.append(np.array(resized_image))
            labels.append(label)
    return data, labels

# Função para criar o modelo
def create_model():
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet', 
        include_top=False, 
        input_shape=(224, 224, 3)
    )
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(num_classes, activation='softmax')(x)  # Agora com 3 classes
    
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Função para configurar callbacks
def create_callbacks():
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=1, mode='min', min_delta=1e-10)
    checkpoint = ModelCheckpoint("best_model_fold.keras", monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    return [reduce_lr, checkpoint]

# Função para plotar a matriz de confusão
def plot_confusion_matrix(cm, classes, fold=''):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.ylabel('Rótulo verdadeiro')
    plt.xlabel('Rótulo previsto')
    plt.title(f'Matriz de Confusão {fold}')
    plt.show()

# %%
# Visualiza amostras
visualize_samples(B_DIR, 'Carcinoma Basocelular')
visualize_samples(M_DIR, 'Melanoma')
visualize_samples(R_DIR, 'Desconhecido')

# Carrega e prepara dados
basal_data, basal_labels = load_images_from_directory(B_DIR, 0)
melanoma_data, melanoma_labels = load_images_from_directory(M_DIR, 1)
random_data, random_labels = load_images_from_directory(R_DIR, 2)

# Balanceamento das classes
min_class_size = min(len(basal_data), len(melanoma_data), len(random_data))
basal_data = basal_data[:min_class_size]
basal_labels = basal_labels[:min_class_size]
melanoma_data = melanoma_data[:min_class_size]
melanoma_labels = melanoma_labels[:min_class_size]
random_data = random_data[:min_class_size]
random_labels = random_labels[:min_class_size]

# Combina e embaralha os dados
data = np.array(basal_data + melanoma_data + random_data)
labels = np.array(basal_labels + melanoma_labels + random_labels)
shuffled_indices = np.arange(len(data))
np.random.shuffle(shuffled_indices)
data = data[shuffled_indices]
labels = labels[shuffled_indices]

# Salva arrays
np.save("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/feats_train_all", data)
np.save("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/labels_train_all", labels)

# Carrega dados salvos
data = np.load("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/feats_train_all.npy")
labels = np.load("/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/labels_train_all.npy")

# Divide dados em treinamento e teste
split_index = int(0.8 * len(data))
x_train, x_test = data[:split_index], data[split_index:]
y_train, y_test = labels[:split_index], labels[split_index:]

# Normaliza os dados
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
num_classes = len(np.unique(labels))
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# Criação do ImageDataGenerator para aumento de dados
trainAug = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    vertical_flip=False
)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile

# %%
# Cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_val_accuracies = []
best_f1_scores = []
best_model_paths = []

for fold, (train_index, val_index) in enumerate(kf.split(x_train)):
    print(f"Treinando o fold {fold + 1}/{kf.n_splits}...")
    x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    model = create_model()
    
    # Treina o modelo
    model.fit(
        trainAug.flow(x_train_fold, y_train_fold, batch_size=16),
        validation_data=(x_val_fold, y_val_fold),
        epochs=15,
        callbacks=create_callbacks()
    )

    # Avalia o modelo
    val_loss, val_accuracy = model.evaluate(x_val_fold, y_val_fold, verbose=0)
    print(f'Fold {fold + 1} - Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')

    # Plota matriz de confusão para o fold atual
    y_val_pred = model.predict(x_val_fold, batch_size=16)
    y_val_pred_classes = np.argmax(y_val_pred, axis=1)
    y_val_true = np.argmax(y_val_fold, axis=1)
    confusion_mtx = confusion_matrix(y_val_true, y_val_pred_classes)
    plot_confusion_matrix(confusion_mtx, classes=range(num_classes), fold=f'Fold {fold + 1}')

    # Calcula o F1-score para o fold atual
    report = classification_report(y_val_true, y_val_pred_classes, output_dict=True, target_names=['BCC', 'Melanoma', 'Desconhecido'])
    f1_score = (report['BCC']['f1-score'] + report['Melanoma']['f1-score'] + report['Desconhecido']['f1-score']) / 3

    best_val_accuracies.append(val_accuracy)
    best_f1_scores.append(f1_score)
    
    # Salva o melhor modelo
    best_model_path = f'/home/cristiano/www/skin_cancer_prediction/ISIC_2020/coding/skin_model_keras/epoch_all/best_model_fold_{fold + 1}.keras'
    model.save(best_model_path)
    best_model_paths.append(best_model_path)

    # Limpa memória
    del x_train_fold, x_val_fold, y_train_fold, y_val_fold
    gc.collect()

# Calcula médias gerais
mean_val_accuracy = np.mean(best_val_accuracies)
mean_f1_score = np.mean(best_f1_scores)

print(f"Média da Acurácia dos Modelos: {mean_val_accuracy:.4f}")
print(f"Média do F1-Score dos Modelos: {mean_f1_score:.4f}")

# Determina o melhor modelo
best_model_idx = np.argmax(best_val_accuracies)
print(f"O melhor modelo foi o do Fold {best_model_idx + 1} com uma acurácia de {best_val_accuracies[best_model_idx]:.4f}")

# Limpeza final
gc.collect()
# Out:
# Treinando o fold 1/5...
# Epoch 1/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.5707 - loss: 1.0151
# Epoch 1: val_loss improved from inf to 1.56297, saving model to best_model_fold.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 27s 913ms/step - accuracy: 0.5803 - loss: 0.9997 - val_accuracy: 0.5536 - val_loss: 1.5630 - learning_rate: 0.0010
# Epoch 2/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.8655 - loss: 0.3924
# Epoch 2: val_loss improved from 1.56297 to 1.02401, saving model to best_model_fold.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 860ms/step - accuracy: 0.8661 - loss: 0.3897 - val_accuracy: 0.5536 - val_loss: 1.0240 - learning_rate: 0.0010
# Epoch 3/15
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9422 - loss: 0.2417
# Epoch 3: val_loss did not improve from 1.02401
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 12s 843ms/step - accuracy: 0.9389 - loss: 0.2486 - val_accuracy: 0.3214 - val_loss: 12.6031 - learning_rate: 0.0010
# Epoch 4/15
# ...

# %%
# Avaliação final dos modelos no conjunto de teste
all_test_accuracies = []
all_test_f1_scores = []

for idx, model_path in enumerate(best_model_paths):
    print(f"Carregando o modelo do Fold {idx + 1}...")
    model = load_model(model_path)
    
    # Avalia o modelo no conjunto de teste
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    y_test_pred = model.predict(x_test, batch_size=16)
    y_test_pred_classes = np.argmax(y_test_pred, axis=1)
    y_test_true = np.argmax(y_test, axis=1)
    
    # Relatório de classificação para o conjunto de teste
    report = classification_report(y_test_true, y_test_pred_classes, target_names=['BCC', 'Melanoma', 'Desconhecido'])
    print(f"Modelo do Fold {idx + 1} - Relatório de Classificação no teste:\n{report}")
    
    # Calcula a média das métricas
    accuracy = test_accuracy
    f1_scores = classification_report(y_test_true, y_test_pred_classes, output_dict=True, target_names=['BCC', 'Melanoma', 'Desconhecido'])
    f1_score = (f1_scores['BCC']['f1-score'] + f1_scores['Melanoma']['f1-score'] + f1_scores['Desconhecido']['f1-score']) / 3

    all_test_accuracies.append(accuracy)
    all_test_f1_scores.append(f1_score)

# Calcula médias gerais
mean_accuracy = np.mean(all_test_accuracies)
mean_f1_score = np.mean(all_test_f1_scores)

print(f"Média da Acurácia dos Modelos: {mean_accuracy:.4f}")
print(f"Média do F1-Score dos Modelos: {mean_f1_score:.4f}")

# Determina o melhor modelo
best_model_idx = np.argmax(all_test_accuracies)
print(f"O melhor modelo foi o do Fold {best_model_idx + 1} com uma acurácia de {all_test_accuracies[best_model_idx]:.4f}")

# Limpeza final
gc.collect()
# Out:
# Carregando o modelo do Fold 1...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step
# Modelo do Fold 1 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.50      0.05      0.08        22
#     Melanoma       0.00      0.00      0.00        27
# Desconhecido       0.32      1.00      0.49        22
#
#     accuracy                           0.32        71
#    macro avg       0.27      0.35      0.19        71
# weighted avg       0.26      0.32      0.18        71
#
# Carregando o modelo do Fold 2...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 261ms/step
# Modelo do Fold 2 - Relatório de Classificação no teste:
#               precision    recall  f1-score   support
#
#          BCC       0.00      0.00      0.00        22
#     Melanoma       0.47      1.00      0.64        27
# Desconhecido       1.00      0.45      0.62        22
#
#     accuracy                           0.52        71
# ...
